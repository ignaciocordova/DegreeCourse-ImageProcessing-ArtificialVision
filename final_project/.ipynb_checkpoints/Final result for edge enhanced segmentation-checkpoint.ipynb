# %%
import impavi
import skimage
import matplotlib.pyplot as plt

# %%
im_edge_seg = impavi.edge_enhanced_segmentation('DIC_SN_15_L10_Sum00.tif')
original = plt.imread('DIC_SN_15_L10_Sum00.tif')
im_manual = plt.imread('DIC_SN_15_L10_Sum00_manual.png')
im_topman = plt.imread('DIC_SN_15_L10_Sum00_topman.png')
im_tscratch = plt.imread('DIC_SN_15_L10_Sum00_tscratch.png')
im_multiceg_Seg = plt.imread('DIC_SN_15_L10_Sum00_multiCellSeg.png')

plt.figure(figsize=(20,20))
plt.subplot(241)
plt.imshow(original,cmap='gray')

plt.subplot(242)
plt.imshow(im_manual,cmap='gray')

plt.subplot(245)
plt.imshow(im_topman,cmap='gray')

plt.subplot(246)
plt.imshow(im_multiceg_Seg,cmap='gray')

plt.subplot(247)
plt.imshow(im_tscratch,cmap='gray')

plt.subplot(248)
plt.imshow(im_edge_seg,cmap='gray')

# %%
ssim = skimage.metrics.structural_similarity(im_manual,im_edge_seg)
print('The ssim index is',ssim)
# Out:
# /Users/codefrom0/opt/anaconda3/lib/python3.9/site-packages/skimage/_shared/utils.py:293: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   return func(*args, **kwargs)
# The ssim index is 0.9538472248666287

# %%
final = impavi.low_pass_filter(im_edge_seg,0.00006,plot=False)
final_otsu = impavi.otsu_filter(final,plot=False)
plt.figure(figsize=(20,20))
plt.subplot(121)
plt.imshow(im_manual,cmap='gray')
plt.subplot(122)
plt.imshow(final_otsu,cmap='gray')

# %%
ssim = skimage.metrics.structural_similarity(im_manual,final_otsu)
print('The ssim index is',ssim)
# Out:
# The ssim index is 0.9716539549573399
